# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
pd.set_option('display.max_colwidth', None)  # display full content of columns
pd.set_option('display.max_columns', None)  # display full columns of dataframes

# %%
df = pd.read_csv('tiki_product_data.csv')

# %% [markdown]
# # Phân tích dữ liệu về 3 loại sản phẩm điện thoại, laptop và máy tính bảng hiện đang được mở bán trên sàn Tiki (tính đến 11/2024)

# %%
df.columns
# Out:
# Index(['id', 'product_name', 'price(vnd)', 'original_price', 'discount',
#        'discount_rate(%)', 'review_count', 'rating_average', 'quantity_sold',
#        'brand_name', 'origin', 'subcategory_name', 'category_name'],
#       dtype='object')

# %%
# calculate total revenue
df['total_sales_per_product'] = df['price(vnd)'] * df['quantity_sold']

# %%
df.head()
# Out:
#          id                                                    product_name  \
# 0   4048043                               Điện Thoại Bàn Panasonic KX-TS500
# 1   4048581                               Điện Thoại Bàn Panasonic KX-TSC11
# 2  11251711  Điện thoại bàn không dây Panasonic KX-TGD312 - Hàng Chính Hãng
# 3  11251735  Điện thoại bàn không dây Panasonic KX-TGC312 - Hàng chính hãng
# 4  11251743  Điện thoại bàn không dây Panasonic KX-TGB112 - Hàng Chính Hãng
#
#    price(vnd)  original_price  discount  discount_rate(%)  review_count  \
# 0      329000          359000     30000                 8            25
# 1      689000          689000         0                 0             9
# 2     1920000         1920000         0                 0             4
# 3     1750000         1750000         0                 0             1
# 4     1260000         1260000         0                 0             4
#
#    rating_average  quantity_sold brand_name    origin subcategory_name  \
# 0             4.5          314.0  Panasonic       NaN   dien-thoai-ban
# 1             4.5           65.0  Panasonic       NaN   dien-thoai-ban
# 2             4.8            9.0  Panasonic  Việt Nam   dien-thoai-ban
# 3             5.0           11.0  Panasonic       NaN   dien-thoai-ban
# 4             5.0           24.0  Panasonic       NaN   dien-thoai-ban
#
#   category_name  total_sales_per_product
# 0    Điện thoại              103306000.0
# 1    Điện thoại               44785000.0
# 2    Điện thoại               17280000.0
# 3    Điện thoại               19250000.0
# 4    Điện thoại               30240000.0

# %%
df.describe().style.format('{:,.1f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0c16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0c16_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b0c16_level0_col1" class="col_heading level0 col1" >price(vnd)</th>
#       <th id="T_b0c16_level0_col2" class="col_heading level0 col2" >original_price</th>
#       <th id="T_b0c16_level0_col3" class="col_heading level0 col3" >discount</th>
#       <th id="T_b0c16_level0_col4" class="col_heading level0 col4" >discount_rate(%)</th>
#       <th id="T_b0c16_level0_col5" class="col_heading level0 col5" >review_count</th>
#       <th id="T_b0c16_level0_col6" class="col_heading level0 col6" >rating_average</th>
#       <th id="T_b0c16_level0_col7" class="col_heading level0 col7" >quantity_sold</th>
#       <th id="T_b0c16_level0_col8" class="col_heading level0 col8" >total_sales_per_product</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0c16_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b0c16_row0_col0" class="data row0 col0" >855.0</td>
#       <td id="T_b0c16_row0_col1" class="data row0 col1" >855.0</td>
#       <td id="T_b0c16_row0_col2" class="data row0 col2" >855.0</td>
#       <td id="T_b0c16_row0_col3" class="data row0 col3" >855.0</td>
#       <td id="T_b0c16_row0_col4" class="data row0 col4" >855.0</td>
#       <td id="T_b0c16_row0_col5" class="data row0 col5" >855.0</td>
#       <td id="T_b0c16_row0_col6" class="data row0 col6" >855.0</td>
#       <td id="T_b0c16_row0_col7" class="data row0 col7" >855.0</td>
#       <td id="T_b0c16_row0_col8" class="data row0 col8" >855.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b0c16_row1_col0" class="data row1 col0" >241,439,281.3</td>
#       <td id="T_b0c16_row1_col1" class="data row1 col1" >11,649,647.2</td>
#       <td id="T_b0c16_row1_col2" class="data row1 col2" >12,401,230.8</td>
#       <td id="T_b0c16_row1_col3" class="data row1 col3" >751,583.6</td>
#       <td id="T_b0c16_row1_col4" class="data row1 col4" >6.2</td>
#       <td id="T_b0c16_row1_col5" class="data row1 col5" >12.1</td>
#       <td id="T_b0c16_row1_col6" class="data row1 col6" >1.2</td>
#       <td id="T_b0c16_row1_col7" class="data row1 col7" >118.3</td>
#       <td id="T_b0c16_row1_col8" class="data row1 col8" >814,528,641.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b0c16_row2_col0" class="data row2 col0" >56,327,382.9</td>
#       <td id="T_b0c16_row2_col1" class="data row2 col1" >9,200,268.3</td>
#       <td id="T_b0c16_row2_col2" class="data row2 col2" >9,795,063.6</td>
#       <td id="T_b0c16_row2_col3" class="data row2 col3" >1,848,903.2</td>
#       <td id="T_b0c16_row2_col4" class="data row2 col4" >9.8</td>
#       <td id="T_b0c16_row2_col5" class="data row2 col5" >134.9</td>
#       <td id="T_b0c16_row2_col6" class="data row2 col6" >2.1</td>
#       <td id="T_b0c16_row2_col7" class="data row2 col7" >1,045.1</td>
#       <td id="T_b0c16_row2_col8" class="data row2 col8" >7,718,338,999.4</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b0c16_row3_col0" class="data row3 col0" >4,048,043.0</td>
#       <td id="T_b0c16_row3_col1" class="data row3 col1" >182,898.0</td>
#       <td id="T_b0c16_row3_col2" class="data row3 col2" >228,622.0</td>
#       <td id="T_b0c16_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_b0c16_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_b0c16_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_b0c16_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_b0c16_row3_col7" class="data row3 col7" >0.0</td>
#       <td id="T_b0c16_row3_col8" class="data row3 col8" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b0c16_row4_col0" class="data row4 col0" >214,912,245.5</td>
#       <td id="T_b0c16_row4_col1" class="data row4 col1" >3,276,000.0</td>
#       <td id="T_b0c16_row4_col2" class="data row4 col2" >3,745,000.0</td>
#       <td id="T_b0c16_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_b0c16_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_b0c16_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_b0c16_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_b0c16_row4_col7" class="data row4 col7" >0.0</td>
#       <td id="T_b0c16_row4_col8" class="data row4 col8" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b0c16_row5_col0" class="data row5 col0" >273,440,662.0</td>
#       <td id="T_b0c16_row5_col1" class="data row5 col1" >10,000,000.0</td>
#       <td id="T_b0c16_row5_col2" class="data row5 col2" >10,690,000.0</td>
#       <td id="T_b0c16_row5_col3" class="data row5 col3" >0.0</td>
#       <td id="T_b0c16_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_b0c16_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_b0c16_row5_col6" class="data row5 col6" >0.0</td>
#       <td id="T_b0c16_row5_col7" class="data row5 col7" >0.0</td>
#       <td id="T_b0c16_row5_col8" class="data row5 col8" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b0c16_row6_col0" class="data row6 col0" >275,774,825.5</td>
#       <td id="T_b0c16_row6_col1" class="data row6 col1" >18,334,500.0</td>
#       <td id="T_b0c16_row6_col2" class="data row6 col2" >18,990,000.0</td>
#       <td id="T_b0c16_row6_col3" class="data row6 col3" >465,500.0</td>
#       <td id="T_b0c16_row6_col4" class="data row6 col4" >11.0</td>
#       <td id="T_b0c16_row6_col5" class="data row6 col5" >1.0</td>
#       <td id="T_b0c16_row6_col6" class="data row6 col6" >4.0</td>
#       <td id="T_b0c16_row6_col7" class="data row6 col7" >3.0</td>
#       <td id="T_b0c16_row6_col8" class="data row6 col8" >13,967,500.0</td>
#     </tr>
#     <tr>
#       <th id="T_b0c16_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_b0c16_row7_col0" class="data row7 col0" >276,641,263.0</td>
#       <td id="T_b0c16_row7_col1" class="data row7 col1" >44,490,000.0</td>
#       <td id="T_b0c16_row7_col2" class="data row7 col2" >51,990,000.0</td>
#       <td id="T_b0c16_row7_col3" class="data row7 col3" >17,211,000.0</td>
#       <td id="T_b0c16_row7_col4" class="data row7 col4" >60.0</td>
#       <td id="T_b0c16_row7_col5" class="data row7 col5" >3,086.0</td>
#       <td id="T_b0c16_row7_col6" class="data row7 col6" >5.0</td>
#       <td id="T_b0c16_row7_col7" class="data row7 col7" >18,661.0</td>
#       <td id="T_b0c16_row7_col8" class="data row7 col8" >143,098,410,000.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Thống kê số lượng sản phẩm đang được mở bán, doanh thu và tổng số lượt bán theo danh mục hàng hóa và thương hiệu

# %% [markdown]
# ### Thống kê số lượng sản phẩm đang được mở bán và tổng số lượt bán theo danh mục hàng hóa

# %%
df1 = df.groupby(['category_name','subcategory_name'])['quantity_sold'].count().reset_index().rename(columns={'quantity_sold':'total_products'})
df2 = df.groupby(['category_name', 'subcategory_name'])['quantity_sold'].sum().reset_index().rename(columns={'quantity_sold':'total_quantity_sold'})
df3 = df.groupby(['category_name', 'subcategory_name'])['total_sales_per_product'].sum().reset_index().rename(columns={'total_sales_per_product':'total_sales(vnd)'})
df2['total_quantity_sold'] = df2['total_quantity_sold'].apply(lambda x: f'{x:,.0f}')
df3['total_sales(vnd)'] = df3['total_sales(vnd)'].apply(lambda x: f'{x:,.0f}')

# %%
# join 3 dataframes df1, df2, df3
df_1_2 = pd.merge(df1, df2, on=['category_name', 'subcategory_name'])
df_category = pd.merge(df_1_2, df3, on=['category_name', 'subcategory_name'])
df_category
# Out:
#    category_name       subcategory_name  total_products total_quantity_sold  \
# 0         Laptop       laptop-2-trong-1              13                  21
# 1         Laptop          laptop-gaming              53                  56
# 2         Laptop    laptop-truyen-thong             359                 207
# 3         Laptop           macbook-imac               3               3,199
# 4  Máy tính bảng           may-doc-sach              42               3,099
# 5  Máy tính bảng          may-tinh-bang              56               4,900
# 6     Điện thoại         dien-thoai-ban              57               2,845
# 7     Điện thoại   dien-thoai-pho-thong              24               3,515
# 8     Điện thoại  dien-thoai-smartphone             248              83,269
#
#   total_sales(vnd)
# 0       79,230,000
# 1      296,633,000
# 2    1,677,017,255
# 3   58,717,460,000
# 4   11,977,116,100
# 5   31,648,955,000
# 6    1,784,286,700
# 7    2,215,550,000
# 8  588,025,740,000

# %% [markdown]
# * Các sản phẩm **điện thoại smartphone** ghi nhật lượt bán và doanh thu cao vượt trội so với các sản phẩm còn lại

# %% [markdown]
# ### Top các thương hiệu (brand) ghi nhận mức doanh thu cao nhất

# %%
df_by_brand = df.groupby(['category_name', 'brand_name'])['total_sales_per_product'].sum().reset_index().rename(columns={'total_sales_per_product':'total_sales(vnd)'})
df_by_brand_top_10 = df_by_brand.sort_values(by='total_sales(vnd)', ascending=False).head(10)
# df_by_brand_top_10.style.format('{:,.1f}')
df_by_brand_top_10
# Out:
#     category_name brand_name  total_sales(vnd)
# 24     Điện thoại      Apple      4.031416e+11
# 35     Điện thoại       POCO      9.108142e+10
# 1          Laptop      Apple      5.871746e+10
# 33     Điện thoại       OPPO      5.650231e+10
# 9   Máy tính bảng      Apple      2.974429e+10
# 38     Điện thoại    Samsung      2.401760e+10
# 10  Máy tính bảng     Kindle      1.048005e+10
# 43     Điện thoại     Xiaomi      6.589372e+09
# 37     Điện thoại     Realme      5.154848e+09
# 32     Điện thoại      Nokia      2.180924e+09

# %%
sns.barplot(x='brand_name', y='total_sales(vnd)', hue='category_name', data=df_by_brand_top_10)
# Format the y-axis labels with thousands separator
fmt = '{x:,.0f}VND'
tick = mtick.StrMethodFormatter(fmt)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick)

# Customize the plot
plt.title('Total sales by Brand and Category')
plt.xlabel('Brand Name')
plt.ylabel('Total sales')

plt.show()

# %% [markdown]
# * Các sản phẩm của thương hiệu **Apple** ghi nhận mức doanh thu vượt trội với **hơn 400 tỷ VND**.
# * **POCO**, thương hiệu con của Tập đoàn Xiaomi (Trung Quốc) xếp vị trí thứ 2 về doanh thu, tập trung chủ yếu vào điện thoại Smartphone.

# %% [markdown]
# ## Thống kê số lượt bán theo mức giá

# %%
#Price distribution analysis.
price_bins = [0, 1000000, 5000000, 15000000, 25000000, 35000000, 45000000, float("inf")]
price_labels = ["< 1tr","1tr - 5tr","5tr - 15tr","15tr - 25tr","25tr - 35tr","35tr - 45tr",">45tr"]

#Bin the price data.
df["price_range"] = pd.cut(df["price(vnd)"], bins=price_bins,labels=price_labels, right=False)
#Count total quantity sold in each bin.
price_range_counts = df.groupby("price_range")['quantity_sold'].sum()
# #Count the number of products that record revenue in each bin
# products_record_revenue_counts = df.loc[df['quantity_sold'] > 0.0]["price_range"].value_counts().sort_index()


#plot the graph
plt.figure(figsize=(10,6))
price_range_counts.plot(kind="line",marker="o")
plt.ylabel("Total sales quantity")
plt.xlabel("Prince Range")
plt.title("Number of items sold in each Price Range")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_32189/566134803.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_range_counts = df.groupby("price_range")['quantity_sold'].sum()

# %%
price_range_counts
# Out:
# price_range
# < 1tr           6200.0
# 1tr - 5tr      54506.0
# 5tr - 15tr     31268.0
# 15tr - 25tr     4830.0
# 25tr - 35tr     4299.0
# 35tr - 45tr        8.0
# >45tr              0.0
# Name: quantity_sold, dtype: float64

# %% [markdown]
# * Các sản phẩm ghi nhận lượt bán nhiều nhất nằm trong khoảng giá **từ 1 triệu đến 15 triệu đồng.**

# %% [markdown]
# ## Top 5 sản phẩm bán chạy nhất tính đến tháng 11/2024

# %%
df.sort_values(by='quantity_sold', ascending=False).head(5)
# Out:
#             id                                       product_name  price(vnd)  \
# 464  274037360  Điện Thoại POCO C65 (6GB/128GB) - Hàng Chính Hãng     2690000
# 113  184036446                                    Apple iPhone 11     9890000
# 465  274037365  Điện Thoại POCO C65 (8GB/256GB) - Hàng Chính Hãng     2990000
# 349  270975124    Điện Thoại Oppo A58 6GB/128GB - Hàng Chính Hãng     4090000
# 114  184059211                                    Apple iPhone 13    13090000
#
#      original_price  discount  discount_rate(%)  review_count  rating_average  \
# 464         3090000    400000                13            53             4.8
# 113        15999000   6109000                38          3086             4.8
# 465         3590000    600000                17            80             5.0
# 349         4990000    900000                18            82             5.0
# 114        24990000  11900000                48          2022             5.0
#
#      quantity_sold brand_name      origin       subcategory_name  \
# 464        18661.0       POCO  Trung Quốc  dien-thoai-smartphone
# 113        14469.0      Apple  Trung Quốc  dien-thoai-smartphone
# 465        12908.0       POCO  Trung Quốc  dien-thoai-smartphone
# 349         9723.0       OPPO  Trung Quốc  dien-thoai-smartphone
# 114         7844.0      Apple  Trung Quốc  dien-thoai-smartphone
#
#     category_name  total_sales_per_product price_range
# 464    Điện thoại             5.019809e+10   1tr - 5tr
# 113    Điện thoại             1.430984e+11  5tr - 15tr
# 465    Điện thoại             3.859492e+10   1tr - 5tr
# 349    Điện thoại             3.976707e+10   1tr - 5tr
# 114    Điện thoại             1.026780e+11  5tr - 15tr

# %% [markdown]
# * Top 5 sản phẩm bán chạy nhất đều là các sản phẩm điện thoại smartphone với mức giá **nhỏ hơn hoặc bằng 15 triệu**

# %% [markdown]
# ## Top 5 sản phẩm bán chạy nhất theo từng mức giá

# %%
df_top_sold_by_price = df.sort_values(by='quantity_sold', ascending=False)
df_top_sold_by_price = df.groupby('price_range').max('quantity_sold')
pd.merge(df_top_sold_by_price, df, on='id')[['price_range','product_name','price(vnd)_x','quantity_sold_x','total_sales_per_product_x']]
# pd.merge(df_top_sold_by_price, df, on='id')
# Out:
# /tmp/ipykernel_32189/896354719.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_top_sold_by_price = df.groupby('price_range').max('quantity_sold')
#    price_range  \
# 0        < 1tr
# 1    1tr - 5tr
# 2   5tr - 15tr
# 3  15tr - 25tr
# 4  25tr - 35tr
# 5  35tr - 45tr
#
#                                                                                                                                           product_name  \
# 0                                                                                             Bút S Pen Samssung  S24 Ultra màu Xám - Hàng chính hãng
# 1                                                                                                    Điện thoại POCO C75 (8GB/256GB) - Hàng Chính Hãng
# 2                                                                                                Điện Thoại Samsung A16 5G 8GB/128GB - Hàng Chính Hãng
# 3                                                                                                       Điện thoại Xiaomi 14T Pro 5G - Hàng chính hãng
# 4   MSI Cyborg 15 AI A1VEK 053VN (Intel Core Ultra 7 155H | 16GB | 512GB | RTX 4050 GDDR6 | 15.6 inch FHD | Windows 11 Home | Black) - HÀNG CHÍNH HÃNG
# 5  MSI Sword 16 HX B14VFKG 045VN (Intel Core i7-14700HX | 16GB | 1TB SSD | RTX 4060 GDDR6 8GB | 16 inch QHD+ | Win 11 | Cosmos Gray) - HÀNG CHÍNH HÃNG
#
#    price(vnd)_x  quantity_sold_x  total_sales_per_product_x
# 0      999000.0           1423.0               9.107200e+08
# 1     4999000.0          18661.0               5.019809e+10
# 2    14999085.0          14469.0               1.430984e+11
# 3    24990000.0           2946.0               5.285124e+10
# 4    34990000.0           3504.0               1.015810e+11
# 5    44490000.0              8.0               3.079200e+08

# %% [markdown]
# ## Top 5 sản phẩm có discount rate lớn nhất

# %%
df.sort_values(by='discount_rate(%)', ascending=False).head(5)
# Out:
#             id  \
# 824  276448816
# 114  184059211
# 184  206218031
# 774  276285657
# 503  274643985
#
#                                                                                                                                                                                        product_name  \
# 824                                                                                                                                [GIFT] Củ  Sạc Samsung Kèm Cáp Low Standby 45W - Hàng Chính Hãng
# 114                                                                                                                                                                                 Apple iPhone 13
# 184                                                                                                              Máy tính bảng viết tay Xiaomi Wicue màn hình LCD màu cầu vồng không đèn nền 12inch
# 774                                                                                                                                   Máy tính bảng Masstel Tab 8.3 ( 3GB - 32GB) - Hàng Chính Hãng
# 503  Máy vi tính Laptop Asus ExpertBook B1400 (Chip Intel Core i5-1235U | RAM 16GB | SSD 512GB NVMe | 14' Full HD | Bảo mật vân tay | Bảo mật TPM 2.0 | Độ bền chuẩn quân đội US) - Hàng Chính Hãng
#
#      price(vnd)  original_price  discount  discount_rate(%)  review_count  \
# 824      471000         1190000    719000                60             0
# 114    13090000        24990000  11900000                48          2022
# 184      439000          768000    329000                43             0
# 774      950000         1590000    640000                40             3
# 503    13290000        22100000   8810000                40             0
#
#      rating_average  quantity_sold brand_name      origin  \
# 824             0.0          151.0    Samsung  Trung Quốc
# 114             5.0         7844.0      Apple  Trung Quốc
# 184             0.0            0.0        NaN         NaN
# 774             3.3            8.0    Masstel  Trung Quốc
# 503             0.0            0.0        NaN         NaN
#
#           subcategory_name  category_name  total_sales_per_product price_range
# 824  dien-thoai-smartphone     Điện thoại             7.112100e+07       < 1tr
# 114  dien-thoai-smartphone     Điện thoại             1.026780e+11  5tr - 15tr
# 184          may-tinh-bang  Máy tính bảng             0.000000e+00       < 1tr
# 774          may-tinh-bang  Máy tính bảng             7.600000e+06       < 1tr
# 503       laptop-2-trong-1         Laptop             0.000000e+00  5tr - 15tr

# %% [markdown]
# * **Iphone 13** có discount rate nằm trong top 5 và cũng nằm trong top 5 các sản phẩm bán chạy nhất tính đến tháng 11/2024
